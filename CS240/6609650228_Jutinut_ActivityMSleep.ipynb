# %% [markdown]
# Activity MSleep

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_msleep = pd.read_csv("/content/drive/MyDrive/CS240/msleep.csv")

# %% [markdown]
# Practice : Pandas

# %% [markdown]
# To get the average total sleep time for each "vore" category.

# %%
vore_sleep_total = df_msleep.groupby("vore")["sleep_total"].mean()

# %%
vore_sleep_total
# Out:
# vore
# carni      10.378947
# herbi       9.509375
# insecti    14.940000
# omni       10.925000
# Name: sleep_total, dtype: float64

# %% [markdown]
# To find mammals that sleep more than 15 hours per day.

# %%
df_msleep[df_msleep["sleep_total"] > 15]
# Out:
#                               name         genus     vore            order  \
# 1                       Owl monkey         Aotus     omni         Primates
# 17            Long-nosed armadillo       Dasypus    carni        Cingulata
# 19          North American Opossum     Didelphis     omni  Didelphimorphia
# 21                   Big brown bat     Eptesicus  insecti       Chiroptera
# 36            Thick-tailed opposum    Lutreolina    carni  Didelphimorphia
# 42                Little brown bat        Myotis  insecti       Chiroptera
# 50                           Tiger      Panthera    carni        Carnivora
# 61                 Giant armadillo    Priodontes  insecti        Cingulata
# 69          Arctic ground squirrel  Spermophilus    herbi         Rodentia
# 71  Golden-mantled ground squirrel  Spermophilus    herbi         Rodentia
# 75       Eastern american chipmunk        Tamias    herbi         Rodentia
# ...

# %% [markdown]
# If you want the first 10 rows and the name and "sleep_total" columns.

# %%
df_msleep[["name" , "sleep_total"]].head(10)
# Out:
#                          name  sleep_total
# 0                     Cheetah         12.1
# 1                  Owl monkey         17.0
# 2             Mountain beaver         14.4
# 3  Greater short-tailed shrew         14.9
# 4                         Cow          4.0
# 5            Three-toed sloth         14.4
# 6           Northern fur seal          8.7
# 7                Vesper mouse          7.0
# 8                         Dog         10.1
# 9                    Roe deer          3.0

# %% [markdown]
# To select  the row where the index is 5 and columns "name" and "sleep_total"

# %%
df_msleep[["name" , "sleep_total"]].head(5)
# Out:
#                          name  sleep_total
# 0                     Cheetah         12.1
# 1                  Owl monkey         17.0
# 2             Mountain beaver         14.4
# 3  Greater short-tailed shrew         14.9
# 4                         Cow          4.0

# %% [markdown]
# To sort the dataset by "sleep_total" in descending order.

# %%
df_msleep.sort_values('sleep_total', ascending=False)
# Out:
#                       name          genus     vore            order  \
# 42        Little brown bat         Myotis  insecti       Chiroptera
# 21           Big brown bat      Eptesicus  insecti       Chiroptera
# 36    Thick-tailed opposum     Lutreolina    carni  Didelphimorphia
# 61         Giant armadillo     Priodontes  insecti        Cingulata
# 19  North American Opossum      Didelphis     omni  Didelphimorphia
# ..                     ...            ...      ...              ...
# 23                  Donkey          Equus    herbi   Perissodactyla
# 9                 Roe deer      Capreolus    herbi     Artiodactyla
# 22                   Horse          Equus    herbi   Perissodactyla
# 30             Pilot whale  Globicephalus    carni          Cetacea
# 29                 Giraffe        Giraffa    herbi     Artiodactyla
#
#     conservation  sleep_total  sleep_rem  sleep_cycle  awake  brainwt   bodywt
# ...
